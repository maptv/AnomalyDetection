# %%
#######################################################
#######################################################
############    COPYRIGHT - DATA SOCIETY   ############
#######################################################
#######################################################

## ANOMALY DETECTION PART 3 ##

## NOTE: To run individual pieces of code, select the line of code and
##       press ctrl + enter for PCs or command + enter for Macs

# %%
# =================================================-
#### Slide 26: Loading packages  ####

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# =================================================-
#### Slide 27: Directory settings  ####

# Set 'main_dir' to location of the project folder
from pathlib import Path

data_dir = Path.cwd() / "data"

# %%
# =================================================-
#### Slide 28: Load the dataset  ####

from pathlib import Path

data_dir = Path.cwd() / "data"
paysim = pd.read_csv(data_dir / "paysim_transactions.csv")
paysim.head()
# Out:
#    step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   308  CASH_OUT    94270.99   C473084216            0.0             0.0
# 1   215  TRANSFER  1068883.00   C116497934          227.3             0.0
# 2   326  TRANSFER  2485281.21  C2089305953        54940.0             0.0
# 3   371   PAYMENT     2243.36  C1200351076            0.0             0.0
# 4   283   PAYMENT     5845.82  C1501258365            0.0             0.0
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  C1130422007       392411.08       486682.07        0               0
# 1   C321541184      4096905.34      5165788.35        0               0
# 2  C1473680645       177829.59      2663110.80        0               0
# 3  M1583169191            0.00            0.00        0               0
# 4  M1431167213            0.00            0.00        0               0

# %%
# =================================================-
#### Slide 29: Prepare the dataset for modeling  ####

# Drop columns.
paysim = paysim.drop(["step", "type", "nameOrig", "nameDest", "isFlaggedFraud"], axis=1)
paysim.columns
# Out:
# Index(['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
#        'newbalanceDest', 'isFraud'],
#       dtype='object')

# %%
paysim["isFraud"].value_counts(normalize=True)
# Out:
# isFraud
# 0    0.98912
# 1    0.01088
# Name: proportion, dtype: float64

# %%
# ================================================= -
#### Slide 30: LOF on fraud dataset  ####

train, test = train_test_split(paysim, test_size=0.30, random_state=42)

# %%
# Split fraud vs non fraud.
non_fraud = train[train["isFraud"] == 0]

# %%
fraud = train[train["isFraud"] == 1]

# %%
non_fraud = non_fraud.drop("isFraud", axis=1)

# %%
test = pd.concat([test, fraud])

# %%
actual_test = test["isFraud"]

# %%
# =================================================-
#### Slide 31: Create and fit LOF model  ####

lof = LocalOutlierFactor(
    n_neighbors=5, metric="manhattan", contamination=0.01088, novelty=True
)

# model fitting
lof.fit(non_fraud)
# Out:
# LocalOutlierFactor(contamination=0.01088, metric='manhattan', n_neighbors=5,
#                    novelty=True)

# %%
# od_pred = pd.Series(lof.fit_predict(paysim.drop("isFraud", axis=1)))

# %%
# od_pred.value_counts(normalize=True)

# %%
paysim["isFraud"].value_counts(normalize=True)
# Out:
# isFraud
# 0    0.98912
# 1    0.01088
# Name: proportion, dtype: float64

# %%
test
# Out:
#            amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 11167    23835.87       69763.00        45927.13            0.00
# 3912     32952.37       88354.00        55401.63            0.00
# 12717    81393.52      195216.00       113822.48            0.00
# 11660     5357.80           0.00            0.00            0.00
# 4153    165418.39     5628940.42      5794358.81       370554.64
# ...           ...            ...             ...             ...
# 11312   601494.61      601494.61            0.00            0.00
# 4642    186375.38      186375.38            0.00            0.00
# 8050   2451423.58     2451423.58            0.00            0.00
# 9339    918087.96      918087.96            0.00            0.00
# 7629     71666.93       71666.93            0.00        83551.03
#
#        newbalanceDest  isFraud
# 11167            0.00        0
# 3912             0.00        0
# 12717        81393.52        0
# 11660            0.00        0
# 4153        303236.08        0
# ...               ...      ...
# 11312            0.00        1
# 4642             0.00        1
# 8050             0.00        1
# 9339             0.00        1
# 7629        155217.96        1
#
# [6222 rows x 6 columns]

# %%
# =================================================-
#### Slide 32: Test predictions  ####

fraud_pred = lof.predict(test.iloc[:, :-1])

# %%
np.unique(fraud_pred)
# Out:
# array([-1,  1])

# %%
fraud_pred = pd.Series(fraud_pred).map({1: 0, -1: 1})
fraud_pred
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6217    0
# 6218    0
# 6219    1
# 6220    1
# 6221    0
# Length: 6222, dtype: int64

# %%
cmd = metrics.ConfusionMatrixDisplay.from_predictions(actual_test, fraud_pred)
(tn, fp), (fn, tp) = cmd.confusion_matrix

# %%
# ================================================= -
#### Slide 33: Find TPR and TNR  ####

non_fraud_eval = tn / (tn + fp)
print("tnr:", non_fraud_eval)
fraud_eval = tp / (tp + fn)
print("tpr:", fraud_eval)
# Out:
# tnr: 0.9893368877040987
# tpr: 0.2636363636363636

# %%
print(metrics.classification_report(actual_test, fraud_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6002
#            1       0.48      0.26      0.34       220
#
#     accuracy                           0.96      6222
#    macro avg       0.72      0.63      0.66      6222
# weighted avg       0.96      0.96      0.96      6222

# %%
# =================================================-
#### Slide 34: Exercise 1  ####

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import LocalOutlierFactor
from sklearn import metrics
import seaborn as sns

# %%
np.arange(0.001, 0.01, 0.001)
# Out:
# array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009])

# %%
metrics.f1_score
# Out:
# <function sklearn.metrics._classification.f1_score(y_true, y_pred, *, labels=None, pos_label=1, average='binary', sample_weight=None, zero_division='warn')>

# %%
gscv = GridSearchCV(
    LocalOutlierFactor(metric="manhattan", novelty=True),
    {"n_neighbors": range(15, 20), "contamination": np.arange(0.001, 0.009, 0.001)},
    scoring=metrics.make_scorer(metrics.f1_score),
)

y_test = test["isFraud"].map({0: 1, 1: -1})
X_test = test.drop("isFraud", axis=1)

# %%
gscv.fit(X_test, y_test)
# Out:
# GridSearchCV(estimator=LocalOutlierFactor(metric='manhattan', novelty=True),
#              param_grid={'contamination': array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008]),
#                          'n_neighbors': range(15, 20)},
#              scoring=make_scorer(f1_score, response_method='predict'))

# %%
cv_df = pd.DataFrame(gscv.cv_results_)

# %%
piv_df = cv_df.pivot(columns="param_n_neighbors", index="param_contamination", values="mean_test_score")

# %%
piv_df.style.background_gradient(cmap='viridis', low=.5, high=0)
# Out:
# <style type="text/css">
# #T_35733_row0_col0, #T_35733_row0_col1, #T_35733_row0_col2, #T_35733_row0_col3, #T_35733_row0_col4 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_35733_row1_col0 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_35733_row1_col1 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_35733_row1_col2, #T_35733_row1_col3 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_35733_row1_col4 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_35733_row2_col0, #T_35733_row2_col3 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_35733_row2_col1 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_35733_row2_col2, #T_35733_row3_col2 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_35733_row2_col4 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_35733_row3_col0 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_35733_row3_col1 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_35733_row3_col3 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_35733_row3_col4 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_35733_row4_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_35733_row4_col1 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_35733_row4_col2 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_35733_row4_col3 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_35733_row4_col4 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_35733_row5_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_35733_row5_col1 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_35733_row5_col2 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_35733_row5_col3 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_35733_row5_col4 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_35733_row6_col0 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_35733_row6_col1 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_35733_row6_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_35733_row6_col3 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_35733_row6_col4 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_35733_row7_col0, #T_35733_row7_col1, #T_35733_row7_col2, #T_35733_row7_col3, #T_35733_row7_col4 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_35733">
#   <thead>
#     <tr>
#       <th class="index_name level0" >param_n_neighbors</th>
#       <th id="T_35733_level0_col0" class="col_heading level0 col0" >15</th>
#       <th id="T_35733_level0_col1" class="col_heading level0 col1" >16</th>
#       <th id="T_35733_level0_col2" class="col_heading level0 col2" >17</th>
#       <th id="T_35733_level0_col3" class="col_heading level0 col3" >18</th>
#       <th id="T_35733_level0_col4" class="col_heading level0 col4" >19</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_contamination</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35733_level0_row0" class="row_heading level0 row0" >0.001000</th>
#       <td id="T_35733_row0_col0" class="data row0 col0" >0.981136</td>
#       <td id="T_35733_row0_col1" class="data row0 col1" >0.980973</td>
#       <td id="T_35733_row0_col2" class="data row0 col2" >0.981286</td>
#       <td id="T_35733_row0_col3" class="data row0 col3" >0.981311</td>
#       <td id="T_35733_row0_col4" class="data row0 col4" >0.981311</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row1" class="row_heading level0 row1" >0.002000</th>
#       <td id="T_35733_row1_col0" class="data row1 col0" >0.980450</td>
#       <td id="T_35733_row1_col1" class="data row1 col1" >0.980368</td>
#       <td id="T_35733_row1_col2" class="data row1 col2" >0.980613</td>
#       <td id="T_35733_row1_col3" class="data row1 col3" >0.980705</td>
#       <td id="T_35733_row1_col4" class="data row1 col4" >0.980705</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row2" class="row_heading level0 row2" >0.003000</th>
#       <td id="T_35733_row2_col0" class="data row2 col0" >0.980205</td>
#       <td id="T_35733_row2_col1" class="data row2 col1" >0.980285</td>
#       <td id="T_35733_row2_col2" class="data row2 col2" >0.980367</td>
#       <td id="T_35733_row2_col3" class="data row2 col3" >0.980367</td>
#       <td id="T_35733_row2_col4" class="data row2 col4" >0.980527</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row3" class="row_heading level0 row3" >0.004000</th>
#       <td id="T_35733_row3_col0" class="data row3 col0" >0.980040</td>
#       <td id="T_35733_row3_col1" class="data row3 col1" >0.980189</td>
#       <td id="T_35733_row3_col2" class="data row3 col2" >0.980353</td>
#       <td id="T_35733_row3_col3" class="data row3 col3" >0.980178</td>
#       <td id="T_35733_row3_col4" class="data row3 col4" >0.980015</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row4" class="row_heading level0 row4" >0.005000</th>
#       <td id="T_35733_row4_col0" class="data row4 col0" >0.979700</td>
#       <td id="T_35733_row4_col1" class="data row4 col1" >0.980013</td>
#       <td id="T_35733_row4_col2" class="data row4 col2" >0.979932</td>
#       <td id="T_35733_row4_col3" class="data row4 col3" >0.979850</td>
#       <td id="T_35733_row4_col4" class="data row4 col4" >0.979687</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row5" class="row_heading level0 row5" >0.006000</th>
#       <td id="T_35733_row5_col0" class="data row5 col0" >0.979196</td>
#       <td id="T_35733_row5_col1" class="data row5 col1" >0.979359</td>
#       <td id="T_35733_row5_col2" class="data row5 col2" >0.979603</td>
#       <td id="T_35733_row5_col3" class="data row5 col3" >0.979439</td>
#       <td id="T_35733_row5_col4" class="data row5 col4" >0.979358</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row6" class="row_heading level0 row6" >0.007000</th>
#       <td id="T_35733_row6_col0" class="data row6 col0" >0.978692</td>
#       <td id="T_35733_row6_col1" class="data row6 col1" >0.978935</td>
#       <td id="T_35733_row6_col2" class="data row6 col2" >0.979028</td>
#       <td id="T_35733_row6_col3" class="data row6 col3" >0.979028</td>
#       <td id="T_35733_row6_col4" class="data row6 col4" >0.978865</td>
#     </tr>
#     <tr>
#       <th id="T_35733_level0_row7" class="row_heading level0 row7" >0.008000</th>
#       <td id="T_35733_row7_col0" class="data row7 col0" >0.978444</td>
#       <td id="T_35733_row7_col1" class="data row7 col1" >0.978360</td>
#       <td id="T_35733_row7_col2" class="data row7 col2" >0.978277</td>
#       <td id="T_35733_row7_col3" class="data row7 col3" >0.978605</td>
#       <td id="T_35733_row7_col4" class="data row7 col4" >0.978360</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.heatmap(data=piv_df);

# %%
gscv.best_estimator_
# Out:
# LocalOutlierFactor(contamination=0.001, metric='manhattan', n_neighbors=18,
#                    novelty=True)

# %%
gscv.best_score_
# Out:
# 0.9813107529932642

# %%
actual_test.unique()
# Out:
# array([0, 1])

# %%
fraud_pred.unique()
# Out:
# array([0, 1])

# %%
actual_test.unique()
# Out:
# array([0, 1])

# %%
metrics.recall_score(y_true=actual_test, y_pred=fraud_pred)
# Out:
# 0.2636363636363636

# %%
def score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    print(tp)
    return tp / (tp + fn)

# %%
# ================================================= -
#### Slide 41: Optimized LOF model  ####

lof = gscv.best_estimator_

# model fitting
lof.fit(non_fraud)
# Out:
# LocalOutlierFactor(contamination=0.001, metric='manhattan', n_neighbors=18,
#                    novelty=True)

# %%
tn, fp, fn, tp = cmd.confusion_matrix.ravel()

# %%
confusion_matrix(actual_test, fraud_pred)
# Out:
# array([[5938,   64],
#        [ 162,   58]])

# %%
# =================================================-
#### Slide 42: Test predictions  ####

fraud_pred = lof.predict(test.iloc[:, :-1])
tn, fp, fn, tp = confusion_matrix(actual_test.map({0: 1, 1: -1}), fraud_pred).ravel()
non_fraud_eval = tn / (tn + fp)
print(non_fraud_eval)
# Out:
# 0.02727272727272727

# %%
fraud_eval = tp / (tp + fn)
print(fraud_eval)
# Out:
# 0.9988337220926358

# %%
# =================================================-
#### Slide 43: Load performance_df dataframe  ####

perf_df = pd.read_pickle(data_dir / "performance-metrics_anomaly-detection.pkl")

# %%
perf_df
# Out:
#    precision    recall  f1-score  support           model  accuracy
# 0   0.995022  0.999500  0.997256   5999.0  dtree_no_smote  0.994560
# 1   0.925000  0.552239  0.691589     67.0  dtree_no_smote  0.994560
# 0   0.998613  0.960160  0.979009   5999.0     dtree_smote  0.959281
# 1   0.197987  0.880597  0.323288     67.0     dtree_smote  0.959281

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(
    actual_test, pd.Series(fraud_pred).map({1: 0, -1: 1})
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6002
#            1       0.46      0.03      0.05       220
#
#     accuracy                           0.96      6222
#    macro avg       0.71      0.51      0.52      6222
# weighted avg       0.95      0.96      0.95      6222

# %%
perf_df = pd.concat([
    perf_df,
    pd.DataFrame(classification_report(
        actual_test, pd.Series(fraud_pred).map({1: 0, -1: 1}), output_dict=True
    )).T.head(2).assign(
        model="lof_novelty",
        accuracy=accuracy_score(actual_test, fraud_pred))
])

# %%
perf_df
# Out:
#    precision    recall  f1-score  support           model  accuracy
# 0   0.995022  0.999500  0.997256   5999.0  dtree_no_smote  0.994560
# 1   0.925000  0.552239  0.691589     67.0  dtree_no_smote  0.994560
# 0   0.998613  0.960160  0.979009   5999.0     dtree_smote  0.959281
# 1   0.197987  0.880597  0.323288     67.0     dtree_smote  0.959281
# 0   0.965534  0.998834  0.981902   6002.0     lof_novelty  0.034394
# 1   0.461538  0.027273  0.051502    220.0     lof_novelty  0.034394

# %%
perf_df.to_pickle(data_dir / "dtree-lof_performance-metrics.pickle")

# %%
# =================================================-
#### Slide 45: Exercise 2  ####

# %%
#######################################################
#######################################################
############    COPYRIGHT - DATA SOCIETY   ############
#######################################################
#######################################################

## ANOMALY DETECTION PART 4 ##

## NOTE: To run individual pieces of code, select the line of code and
##       press ctrl + enter for PCs or command + enter for Macs

# %%
# =================================================-
#### Slide 2: Loading packages  ####

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest

# %%
# =================================================-
#### Slide 5: Data: load energy consumption  ####

pjm_energy = pd.read_csv(data_dir / "PJME_hourly.csv", parse_dates=["Datetime"], index_col="Datetime")
pjm_energy.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
# =================================================-
#### Slide 6: Data: preprocessing  ####

pjm_energy.info()
pjm_energy = pjm_energy["2018":]
pjm_energy.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145366 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJME_MW  145366 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB
# (5136, 1)

# %%
# =================================================-
#### Slide 9: Create and fit LOF model: energy consumption  ####

lof_energy_model = LocalOutlierFactor(
    n_neighbors=50, metric="manhattan", contamination=0.01, novelty=False
)

pjm_energy["anomaly"] = lof_energy_model.fit_predict(
    pd.DataFrame(pjm_energy["PJME_MW"])
)

# %%
pjm_energy["PJME_MW"].plot.box()
# Out:
# <Axes: >

# %%
pjm_energy = pjm_energy.reset_index()

# %%
# =================================================-
#### Slide 11: LOF - visualize anomalies  ####

lower_threshold = pjm_energy["PJME_MW"].quantile(0.25)
upper_threshold = pjm_energy["PJME_MW"].quantile(0.75)
lof_anomalies = pjm_energy[pjm_energy["anomaly"] == -1]
# Upper range of anomalies
lof_upper_anomalies = lof_anomalies[lof_anomalies["PJME_MW"] > upper_threshold][
    "PJME_MW"
]

# Lower range of anomalies
lof_lower_anomalies = lof_anomalies[lof_anomalies["PJME_MW"] < lower_threshold][
    "PJME_MW"
]

# %%
pjm_energy = pjm_energy.sort_values("Datetime")

# %%
fig, ax = plt.subplots(figsize=(17, 6))
ax.plot(pjm_energy["Datetime"], pjm_energy["PJME_MW"], color="blue", label="Normal", zorder=1)
ax.scatter(lof_anomalies["Datetime"], lof_anomalies["PJME_MW"], color="red", edgecolor="k", linewidths=.4, label="Anomaly", zorder=9)
plt.legend();

# %%
plt.rcParams.update({"font.size": 20})
plt.hist(lof_lower_anomalies)
plt.xlabel("Anomaly points")
plt.ylabel("Frequency")
plt.title("Lower range of anomalies");

# %%
plt.hist(lof_upper_anomalies)
plt.xlabel("Anomaly points")
plt.ylabel("Frequency")
plt.title("Upper range of anomalies");

# %%
# =================================================-
#### Slide 13: Exercise 3  ####

# %%
non_fraud.columns
# Out:
# Index(['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
#        'newbalanceDest'],
#       dtype='object')

# %%
# =================================================-
#### Slide 24: Create and fit isolation forest model  ####

iforest = IsolationForest(contamination=0.1, random_state=42)

# model fitting
iforest.fit(non_fraud)
# Out:
# IsolationForest(contamination=0.1, random_state=42)

# %%
# =================================================-
#### Slide 25: Test predictions  ####

fraud_pred = iforest.predict(test.iloc[:, :-1])
fraud_pred
# Out:
# array([ 1,  1,  1, ..., -1,  1,  1])

# %%
pd.Series(fraud_pred).value_counts(normalize=True)
# Out:
#  1    0.888139
# -1    0.111861
# Name: proportion, dtype: float64

# %%
actual_test
# Out:
# 11167    0
# 3912     0
# 12717    0
# 11660    0
# 4153     0
#         ..
# 11312    1
# 4642     1
# 8050     1
# 9339     1
# 7629     1
# Name: isFraud, Length: 6222, dtype: int64

# %%
fraud_pred
# Out:
# array([ 1,  1,  1, ..., -1,  1,  1])

# %%
cmd = metrics.ConfusionMatrixDisplay.from_predictions(actual_test, pd.Series(fraud_pred).map({-1: 1, 1: 0}))
tn, fp, fn, tp = cmd.confusion_matrix.ravel()

tnr = tn / (tn + fp)
tpr = tp / (tp + fn)

# %%
perf_df = pd.concat([
    perf_df,
    pd.DataFrame(classification_report(
        actual_test, pd.Series(fraud_pred).map({-1: 1, 1: 0}), output_dict=True
    )).T.head(2).assign(
        model="isolation forest",
        accuracy=accuracy_score(actual_test, fraud_pred))
])

# %%
perf_df
# Out:
#    precision    recall  f1-score  support             model  accuracy
# 0   0.995022  0.999500  0.997256   5999.0    dtree_no_smote  0.994560
# 1   0.925000  0.552239  0.691589     67.0    dtree_no_smote  0.994560
# 0   0.998613  0.960160  0.979009   5999.0       dtree_smote  0.959281
# 1   0.197987  0.880597  0.323288     67.0       dtree_smote  0.959281
# 0   0.965534  0.998834  0.981902   6002.0       lof_novelty  0.034394
# 1   0.461538  0.027273  0.051502    220.0       lof_novelty  0.034394
# 0   0.974122  0.896868  0.933900   6002.0  isolation forest  0.022983
# 1   0.110632  0.350000  0.168122    220.0  isolation forest  0.022983

# %%
perf_df.to_pickle(data_dir / "dtree-lof-if_performance-metrics.pickle")

# %%
# =================================================-
#### Slide 30: Exercise 4  ####

# %%
# =================================================-
#### Slide 32: Isolation forest on time series data  ####

isolation_energy = IsolationForest(n_estimators=100, contamination=0.01)

# model fitting
isolation_energy.fit(pd.DataFrame(pjm_energy["PJME_MW"]))
pjm_energy["anomaly"] = isolation_energy.predict(pd.DataFrame(pjm_energy["PJME_MW"]))

# %%
pjm_energy = pjm_energy.sort_values("Datetime")

# %%
fig, ax = plt.subplots(figsize=(15, 5))
a = pjm_energy.loc[pjm_energy["anomaly"] == -1, ["Datetime", "PJME_MW"]]  # anomaly
ax.plot(pjm_energy["Datetime"], pjm_energy["PJME_MW"], color="blue", label="Normal")
ax.scatter(a["Datetime"], a["PJME_MW"], color="red", edgecolor="k", linewidths=.4, label="Anomaly")
plt.legend();

# %%
# =================================================-
#### Slide 34: Isolation forest - visualize anomalies  ####

# visualization
lower_threshold = pjm_energy["PJME_MW"].quantile(0.25)
upper_threshold = pjm_energy["PJME_MW"].quantile(0.75)
if_anomalies = pjm_energy[pjm_energy["anomaly"] == -1]

if_upper_anomalies = if_anomalies[if_anomalies["PJME_MW"] > upper_threshold]["PJME_MW"]
if_lower_anomalies = if_anomalies[if_anomalies["PJME_MW"] < lower_threshold]["PJME_MW"]

# %%
plt.hist(if_lower_anomalies)
plt.xlabel("Anomaly points")
plt.ylabel("Frequency")
plt.title("Lower range of anomalies")
plt.show()
plt.hist(if_upper_anomalies)
plt.xlabel("Anomaly points")
plt.ylabel("Frequency")
plt.title("Upper range of anomalies")
plt.show()
plt.hist(lof_upper_anomalies, alpha=0.5, label="LOF anomalies")
plt.hist(if_upper_anomalies, alpha=0.5, label="IF anomalies")
plt.title("Upper range of anomalies")
plt.legend(loc="upper right")
plt.show()
plt.hist(lof_lower_anomalies, alpha=0.5, label="LOF anomalies")
plt.hist(if_lower_anomalies, alpha=0.5, label="IF anomalies")
plt.title("Lower range of anomalies")
plt.legend(loc="upper right")
plt.show()

# %%
# =================================================-
#### Slide 37: Exercise 5  ####


#######################################################
####  CONGRATULATIONS ON COMPLETING THIS MODULE!   ####
#######################################################
